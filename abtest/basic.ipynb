# %%
import pandas as pd
import numpy as np

# %%
purchase_data = pd.read_csv('data/purchase_data_v1.csv')
print(purchase_data.head())

purchase_data['date'] = pd.to_datetime(purchase_data['date'])

# Extract the 'day' value from the timestamp
purchase_data.date = purchase_data.date.dt.floor('d')

# Replace the NaN price values with 0 
purchase_data.price = np.where(np.isnan(purchase_data.price), 0, purchase_data.price)

# Aggregate the data by 'uid' & 'date'
purchase_data_agg = purchase_data.groupby(by=['uid', 'date'], as_index=False).sum()

# Calculate the final average
revenue_user_day = purchase_data_agg.price.mean()
print(revenue_user_day)
# Out:
#          date       uid            sku  price
# 0  2017-07-10  41195147  sku_three_499    499
# 1  2017-07-15  41195147  sku_three_499    499
# 2  2017-11-12  41195147   sku_four_599    599
# 3  2017-09-26  91591874    sku_two_299    299
# 4  2017-12-01  91591874   sku_four_599    599
# 407.95033407572384

# %%
# Load demographic and paywall view data
demographics_data = pd.read_csv('data/user_demographics_v1.csv')
paywall_views = pd.read_csv('data/AB_testing_exercise.csv')

# Merge the datasets
merged_data = demographics_data.merge(paywall_views,  how='inner', on=['uid'])
merged_data['date'] = pd.to_datetime(merged_data['date'])
merged_data.date = merged_data.date.dt.floor('d')

# Group and aggregate our combined dataset
daily_purchase_data = merged_data.groupby(by=['date'], as_index=False)
daily_purchase_data = daily_purchase_data.agg({'purchase': ['sum', 'count']})

# Find the mean of each field and then multiply by 1000 to scale the result
daily_purchases = daily_purchase_data.purchase['sum'].mean()
daily_paywall_views = daily_purchase_data.purchase['count'].mean()
daily_purchases = daily_purchases * 1000
daily_paywall_views = daily_paywall_views * 1000

print(f"Daily Purchases: {daily_purchases}")
print(f"Daily Paywall Views: {daily_paywall_views}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 12
#      10 # Group and aggregate our combined dataset
#      11 daily_purchase_data = merged_data.groupby(by=['date'], as_index=False)
# ---> 12 daily_purchase_data = daily_purchase_data.agg({'purchase': ['sum', 'count']})
#      14 # Find the mean of each field and then multiply by 1000 to scale the result
#      15 daily_purchases = daily_purchase_data.purchase['sum'].mean()
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
# ...
